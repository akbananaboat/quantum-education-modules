# %% [markdown]
# # Variational Quantum Classifier Algorithm
#
# (short explanation of algorithm)

# %% [markdown]
# ## 1. Overview
#
# (what is VQC, what is it used for, why is it better than classical computers, pros and cons of algo, general information)

# %% [markdown]
# ## 2. VQC Algorithm Steps:
#
# breaking down the algorithm into steps and explaining each one
#
# - include flowchart/image of how algo works

# %% [markdown]
# ## 3. Qiskit Implementation - maybe...?
